# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# #  My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Kyne Wigle**
# <br>
# Data Scientist

# %% [markdown]
# *I am interested into data science because I love analysing data and turning it into useful and information.*

# %% [markdown]
# ### The code below will display the value of pi.

# %%
# Import math to get pi
import math

pi = math.pi
print(pi)

# Returns the numerical value of pi
# Out:
# 3.141592653589793

# %% [markdown]
# ### My Favourite Board Games
# -------------------------------
# | Game | Picture |
# |---------------|-------------|
# | 1. War of the Ring | - ![Screenshot 2023-02-15 at 9.41.18 AM.png](attachment:dcb49022-ebc7-434a-828b-e63bc175352b.png) |
# | 2. Gaia Project | - ![Screenshot 2023-02-15 at 9.41.28 AM.png](attachment:04992bf3-61af-4751-9216-9a409ed9cffb.png) |
# | 3. Spirit Island | - ![Screenshot 2023-02-15 at 9.41.42 AM.png](attachment:17507f8e-c6e1-4a42-830c-e8033f7749df.png) |
